# %%
import pandas as pd

# %%
path = r"C:\Users\amac\Documents\Development\1017-zillow_selenium_scrapper_rel\result.csv"

# %%
df=pd.read_csv(path,sep=';')

# %%
df.head()
# Out:
#   Unique Property ID Full Address                  Sale Status  \
# 0                NaN            4                      1 space
# 1                  3      1 space  725-North-57th-Avenue-Omaha
# 2                NaN            5                     2 spaces
# 3                  4      1 space  709-North-58th-Street-Omaha
# 4                  4      1 space  709-North-58th-Street-Omaha
#
#                         Amount Zestimate           Beds          Baths  \
# 0  722-North-57th-Street-Omaha   725,361              0  Single Family
# 1                      326,602         0  Single Family           None
# 2  716-North-57th-Avenue-Omaha   746,715              0  Single Family
# 3                      433,794   470,000  Single Family           None
# 4                      433,794   470,000  Single Family           None
#
#          Type  Year Built  Heating       ...         URL EventID     Event  \
# 0        None  OFF MARKET    Other       ...        1931     3.5       NaN
# ...
